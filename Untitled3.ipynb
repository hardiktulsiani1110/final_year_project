# %%
pip install --quiet tensorflow-text
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#     crit = self.state.criteria[name]
# KeyError: 'tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\hardi\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\hardi\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\hardi\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\hardi\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\hardi\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#     self._result = resolver.resolve(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 347, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name, criterion)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 207, in _attempt_to_pin_criterion
#     criteria = self._get_criteria_to_update(candidate)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 199, in _get_criteria_to_update
#     name, crit = self._merge_into_criterion(r, parent=candidate)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#     crit = Criterion.from_requirement(self._p, requirement, parent)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#     if not cands:
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#     return any(self)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#     candidate = func()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\hardi\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %%
import tensorflow_hub as hub
import tensorflow_text as text
# Out:
# Failed to import tensorflow. Please note that tensorflow is not installed by default when you install tensorflow_hub. This is so that users can decide which tensorflow package to use. To use tensorflow_hub, please install a current version of tensorflow by following the instructions at https://tensorflow.org/install and https://tensorflow.org/hub/installation.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-566f9fbfe6f7> in <module>
# ----> 1 import tensorflow_hub as hub
#       2 import tensorflow_text as text
#
# ~\anaconda3\lib\site-packages\tensorflow_hub\__init__.py in <module>
#      83             present=tf.__version__))
#      84
# ---> 85 _ensure_tf_install()
#      86
#      87
#
# ~\anaconda3\lib\site-packages\tensorflow_hub\__init__.py in _ensure_tf_install()
#      47   """
#      48   try:
# ---> 49     import tensorflow as tf
#      50   except ImportError:
#      51     # Print more informative error message, then reraise.
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow_hub
# Out:
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Collecting protobuf>=3.8.0
#   Downloading protobuf-4.21.12-cp38-cp38-win_amd64.whl (527 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow_hub) (1.20.1)
# Installing collected packages: protobuf, tensorflow-hub
# Successfully installed protobuf-4.21.12 tensorflow-hub-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp38-cp38-win_amd64.whl (266.3 MB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#     crit = self.state.criteria[name]
# KeyError: 'tensorflow-intel'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\hardi\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\hardi\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\hardi\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\hardi\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\hardi\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#     self._result = resolver.resolve(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 347, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name, criterion)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 207, in _attempt_to_pin_criterion
#     criteria = self._get_criteria_to_update(candidate)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 199, in _get_criteria_to_update
#     name, crit = self._merge_into_criterion(r, parent=candidate)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#     crit = Criterion.from_requirement(self._p, requirement, parent)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#     if not cands:
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#     return any(self)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#     candidate = func()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 159, in iter
#     for x in it:
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\hardi\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\hardi\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %%
import tensorflow as tf

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\hardi\anaconda3\lib\site-packages (21.0.1)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0.1
#     Uninstalling pip-21.0.1:
#       Successfully uninstalled pip-21.0.1
# Successfully installed pip-22.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.11.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp38-cp38-win_amd64.whl (266.3 MB)
#      -------------------------------------- 266.3/266.3 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (52.0.0.post20210125)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 5.3 MB/s eta 0:00:00
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ---------------------------------------- 6.0/6.0 MB 5.6 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      -------------------------------------- 439.2/439.2 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.4.3)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      -------------------------------------- 124.6/124.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.15.0)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 4.7 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp38-cp38-win_amd64.whl (896 kB)
#      -------------------------------------- 896.1/896.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.10.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp38-cp38-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 4.4 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
#      ---------------------------------------- 14.2/14.2 MB 4.8 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      -------------------------------------- 65.5/65.5 kB 708.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.1)
# Requirement already satisfied: packaging in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (20.9)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hardi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.36.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.0.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
#      ------------------------------------ 177.0/177.0 kB 410.8 kB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.25.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.3/93.3 kB 2.6 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      -------------------------------------- 781.3/781.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hardi\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (2.4.7)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      -------------------------------------- 155.3/155.3 kB 2.3 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-5.1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\hardi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.1/77.1 kB 4.5 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, keras, importlib-metadata, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-22.12.6 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 importlib-metadata-5.1.0 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1

# %%
import tensorflow_hub as hub
import tensorflow_text as text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-566f9fbfe6f7> in <module>
#       1 import tensorflow_hub as hub
# ----> 2 import tensorflow_text as text
#
# ModuleNotFoundError: No module named 'tensorflow_text'

# %%
pip install tensorflow_text
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow_text
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install  -U tensorflow-text==2.6.0
# Out:
# Collecting tensorflow-text==2.6.0
#   Downloading tensorflow_text-2.6.0-cp38-cp38-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 97.2 kB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.8.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow-text==2.6.0) (0.12.0)
# Collecting tensorflow<2.7,>=2.6.0
#   Downloading tensorflow-2.6.5-cp38-cp38-win_amd64.whl (429.2 MB)
#      -------------------------------------- 429.2/429.2 MB 1.9 MB/s eta 0:00:00
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.12.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.19.6)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel~=0.35 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.36.2)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.0/132.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: gast==0.4.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.51.1)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      -------------------------------------- 462.9/462.9 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta~=0.2 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.2.0)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.6/42.6 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<3.11,>=3.7 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.7.4.3)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
#      ---------------------------------------- 13.3/13.3 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.15.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.15.0)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.3.0)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (52.0.0.post20210125)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (2.25.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      -------------------------------------- 152.9/152.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\hardi\anaconda3\lib\site-packages (from tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.0.1)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hardi\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hardi\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hardi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\hardi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (5.1.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hardi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (1.26.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\hardi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hardi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hardi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow<2.7,>=2.6.0->tensorflow-text==2.6.0) (3.2.2)
# Building wheels for collected packages: clang, termcolor
#   Building wheel for clang (setup.py): started
#   Building wheel for clang (setup.py): finished with status 'done'
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30702 sha256=d34ccd02ba8bc0779aef558f4fdb8abd86684bed45c071ecc81182796368d45a
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\e6\14\42\cfe861873e629c03755e9dad8c0cbeaa4a9952f5e9dd75125b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=629b813a05aeda3dba3b916152b8dbf72dd3bb6a7753f0a0778a75a64f4b26ee
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\f7\de\e8\f6aec43099b5f725a5227572d0d67a987bc444298b4f14d745
# Successfully built clang termcolor
# Installing collected packages: termcolor, tensorflow-estimator, keras, flatbuffers, clang, numpy, cachetools, absl-py, keras-preprocessing, h5py, google-auth, tensorboard, tensorflow, tensorflow-text
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.1.1
#     Uninstalling termcolor-2.1.1:
#       Successfully uninstalled termcolor-2.1.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 22.12.6
#     Uninstalling flatbuffers-22.12.6:
#       Successfully uninstalled flatbuffers-22.12.6
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\hardi\\anaconda3\\Lib\\site-packages\\tensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.1
#     Uninstalling numpy-1.20.1:
#       Successfully uninstalled numpy-1.20.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.2.0
#     Uninstalling cachetools-5.2.0:
#       Successfully uninstalled cachetools-5.2.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.3.0
#     Uninstalling absl-py-1.3.0:
#       Successfully uninstalled absl-py-1.3.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.15.0
#     Uninstalling google-auth-2.15.0:
#       Successfully uninstalled google-auth-2.15.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.0
#     Uninstalling tensorboard-2.11.0:
#       Successfully uninstalled tensorboard-2.11.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
#   Rolling back uninstall of tensorflow
#   Moving to c:\users\hardi\anaconda3\lib\site-packages\tensorflow-2.11.0.dist-info\
#    from C:\Users\hardi\anaconda3\Lib\site-packages\~ensorflow-2.11.0.dist-info
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\hardi\\anaconda3\\lib\\site-packages\\absl_py-1.3.0.dist-info\\METADATA'
# Collecting tensorflow_text
#   Using cached tensorflow_text-2.10.0-cp38-cp38-win_amd64.whl (5.0 MB)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow_text) (0.12.0)
# Collecting tensorflow<2.11,>=2.10.0
#   Downloading tensorflow-2.10.1-cp38-cp38-win_amd64.whl (455.9 MB)
#      -------------------------------------- 455.9/455.9 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.20.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.51.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.0)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.12.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (22.12.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.6.3)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (14.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.0)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ---------------------------------------- 5.9/5.9 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.19.6)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      -------------------------------------- 438.7/438.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.15.0)
# Requirement already satisfied: setuptools in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (52.0.0.post20210125)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.28.0)
# Requirement already satisfied: packaging in c:\users\hardi\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (20.9)
